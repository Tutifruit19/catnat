# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. GETTING FAMILIAR WITH THE IBTRACS DATABASE

# %% [markdown]
# ## 1.1

# %%
datas = pd.read_csv('INPUTS/ibtracs.ALL.list.hotel1.csv',low_memory=False,header=1)

# %%
datas
# Out:
#                   SID  SEASON  NUMBER BASIN SUBBASIN       NAME  \
# 0       1842298N11080    1842       1    NI       BB  NOT_NAMED
# 1       1842298N11080    1842       1    NI       BB  NOT_NAMED
# 2       1842298N11080    1842       1    NI       BB  NOT_NAMED
# 3       1842298N11080    1842       1    NI       BB  NOT_NAMED
# 4       1842298N11080    1842       1    NI       BB  NOT_NAMED
# ...               ...     ...     ...   ...      ...        ...
# 680887  2019043S14165    2019       9    SP       MM        OMA
# 680888  2019043S14165    2019       9    SP       MM        OMA
# 680889  2019043S14165    2019       9    SP       MM        OMA
# 680890  2019043S14165    2019       9    SP       MM        OMA
# 680891  2019043S14165    2019       9    SP       MM        OMA
#
#                    ISO_TIME NATURE      LAT       LON  ... BOM_GUST_PER  \
# 0       1842-10-25 03:00:00     NR  10.9000   80.3000  ...
# 1       1842-10-25 06:00:00     NR  10.8709   79.8265  ...
# 2       1842-10-25 09:00:00     NR  10.8431   79.3524  ...
# 3       1842-10-25 12:00:00     NR  10.8188   78.8772  ...
# 4       1842-10-25 15:00:00     NR  10.8000   78.4000  ...
# ...                     ...    ...      ...       ...  ...          ...
# 680887  2019-02-13 12:00:00     NR -14.0000  165.0000  ...
# 680888  2019-02-13 15:00:00     NR -14.3051  165.1850  ...
# 680889  2019-02-13 18:00:00     NR -14.7000  165.4000  ...
# 680890  2019-02-13 21:00:00     NR -14.8024  165.4930  ...
# 680891  2019-02-14 00:00:00     NR -14.7000  165.5000  ...
#
#        REUNION_GUST REUNION_GUST_PER USA_SEAHGT  USA_SEARAD_NE USA_SEARAD_SE  \
# 0
# 1
# 2
# 3
# 4
# ...             ...              ...        ...            ...           ...
# 680887
# 680888
# 680889
# 680890
# 680891
#
#        USA_SEARAD_SW USA_SEARAD_NW STORM_SPEED STORM_DIR
# 0                                            9       266
# 1                                            9       267
# 2                                            9       267
# 3                                            9       267
# 4                                            9       268
# ...              ...           ...         ...       ...
# 680887                                       2       100
# 680888                                       8       151
# 680889                                       6       149
# 680890                                       1        90
# 680891                                       2        12
#
# [680892 rows x 163 columns]

# %% [markdown]
# ## 1.2

# %%
print("Il y'a "+str(np.shape(datas)[0])+" lignes et "+str(np.shape(datas)[1])+" colonnes.")
# Out:
# Il y'a 680892 lignes et 163 colonnes.

# %% [markdown]
# ## 1.3

# %%
datas.describe
# Out:
# <bound method NDFrame.describe of                   SID  SEASON  NUMBER BASIN SUBBASIN       NAME  \
# 0       1842298N11080    1842       1    NI       BB  NOT_NAMED
# 1       1842298N11080    1842       1    NI       BB  NOT_NAMED
# 2       1842298N11080    1842       1    NI       BB  NOT_NAMED
# 3       1842298N11080    1842       1    NI       BB  NOT_NAMED
# 4       1842298N11080    1842       1    NI       BB  NOT_NAMED
# ...               ...     ...     ...   ...      ...        ...
# 680887  2019043S14165    2019       9    SP       MM        OMA
# 680888  2019043S14165    2019       9    SP       MM        OMA
# 680889  2019043S14165    2019       9    SP       MM        OMA
# 680890  2019043S14165    2019       9    SP       MM        OMA
# 680891  2019043S14165    2019       9    SP       MM        OMA
#
#                    ISO_TIME NATURE      LAT       LON  ... BOM_GUST_PER  \
# 0       1842-10-25 03:00:00     NR  10.9000   80.3000  ...
# 1       1842-10-25 06:00:00     NR  10.8709   79.8265  ...
# 2       1842-10-25 09:00:00     NR  10.8431   79.3524  ...
# 3       1842-10-25 12:00:00     NR  10.8188   78.8772  ...
# 4       1842-10-25 15:00:00     NR  10.8000   78.4000  ...
# ...                     ...    ...      ...       ...  ...          ...
# 680887  2019-02-13 12:00:00     NR -14.0000  165.0000  ...
# 680888  2019-02-13 15:00:00     NR -14.3051  165.1850  ...
# 680889  2019-02-13 18:00:00     NR -14.7000  165.4000  ...
# 680890  2019-02-13 21:00:00     NR -14.8024  165.4930  ...
# 680891  2019-02-14 00:00:00     NR -14.7000  165.5000  ...
#
#        REUNION_GUST REUNION_GUST_PER USA_SEAHGT  USA_SEARAD_NE USA_SEARAD_SE  \
# 0
# 1
# 2
# 3
# 4
# ...             ...              ...        ...            ...           ...
# 680887
# 680888
# 680889
# 680890
# 680891
#
#        USA_SEARAD_SW USA_SEARAD_NW STORM_SPEED STORM_DIR
# 0                                            9       266
# 1                                            9       267
# 2                                            9       267
# 3                                            9       267
# 4                                            9       268
# ...              ...           ...         ...       ...
# 680887                                       2       100
# 680888                                       8       151
# 680889                                       6       149
# 680890                                       1        90
# 680891                                       2        12
#
# [680892 rows x 163 columns]>

# %% [markdown]
# ## 1.4

# %%
print("Le plus ancien cyclone a été relevé en: "+str(min(datas["SEASON"])))
# Out:
# Le plus ancien cyclone a été relevé en: 1842

# %% [markdown]
# ## 1.5

# %%
datas["NATURE"].value_counts()
# Out:
# TS    479658
# NR    158743
# ET     26497
# DS      6787
# MX      6671
# SS      2536
# Name: NATURE, dtype: int64

# %% [markdown]
# Les systèmes tropicales ("TS") sont les plus prédominants.

# %% [markdown]
# # 2. ANALYSIS OF TROPICAL SYSTEMS PER BASIN

# %% [markdown]
# ## 2.1

# %%
SID_and_year = datas[["SID","SEASON"]]
moyenne = np.mean(SID_and_year.drop_duplicates(subset="SID",keep="first").value_counts("SEASON"))
print("En moyenne, par année le nombre de cyclone est de: "+str(moyenne))
# Out:
# En moyenne, par année le nombre de cyclone est de: 77.97674418604652

# %% [markdown]
# ## 2.2

# %%
SID_year_basin = datas[["SID","SEASON","BASIN"]]
df = SID_year_basin.fillna(value='NA', inplace=False) #Interprète la valeur NA pour north atlantic comme un nan sinon.
nom_bassin = df['BASIN'].unique()
annee = df['SEASON'].unique()
for x in nom_bassin:
    if type(x) != float: #On évite le bassin ou le nom est un NaN
        tri_par_bassin = df[df['BASIN'] == x]
        moyenne_bassin = sum(tri_par_bassin.drop_duplicates(subset="SID",keep='first').value_counts("SEASON"))/(len(annee))
        print("Pour le bassin "+x+" ,la moyenne est de "+str(moyenne_bassin)+" par année.")
        print('--------------------------------')
# Out:
# Pour le bassin NI ,la moyenne est de 10.05813953488372 par année.
# --------------------------------
# Pour le bassin SI ,la moyenne est de 17.46511627906977 par année.
# --------------------------------
# Pour le bassin NA ,la moyenne est de 12.924418604651162 par année.
# --------------------------------
# Pour le bassin EP ,la moyenne est de 9.0 par année.
# --------------------------------
# Pour le bassin WP ,la moyenne est de 24.575581395348838 par année.
# --------------------------------
# Pour le bassin SP ,la moyenne est de 7.563953488372093 par année.
# --------------------------------
# Pour le bassin SA ,la moyenne est de 0.011627906976744186 par année.
# --------------------------------

# %% [markdown]
# ## 2.3

# %%
df = datas[["SID","SEASON","BASIN","NATURE"]]
tab = df[df['NATURE']=="TS"].fillna(value='NA', inplace=False)#Interprète la valeur NA pour north atlantic comme un nan sinon.
nom_bassin = tab['BASIN'].unique()
annees = []
nombres_TS = []
for x in nom_bassin:
    tri_par_bassin = tab[tab['BASIN'] == x]
    annee = tri_par_bassin['SEASON'].unique()
    nombre_par_annee = tri_par_bassin.drop_duplicates(subset="SID",keep='first').value_counts("SEASON")
    years = []
    nombres_TS_bassin = []
    for y in annee:
        years.append(y)
        nombres_TS_bassin.append(nombre_par_annee[y])
    annees.append(years)
    nombres_TS.append(nombres_TS_bassin)

# %%
def interpo_zero(annees_ref,annees,liste):
    output = []
    for i in range(len(annees_ref)):
        if annees_ref[i] in annees:
            ind = annees.index(annees_ref[i])
            output.append(liste[ind])
        else:
            output.append(0)
    return output

TS = [nombres_TS[0]]
for i in range(1,len(annees)):
    TS.append(interpo_zero(annees[0],annees[i],nombres_TS[i]))
# Out:
# ['NA' 'EP' 'SI' 'NI' 'SP' 'WP' 'SA']
# 7

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(annees[0],TS[0],width=0.65,label=nom_bassin[0])
for i in range(1,7):
    ax.bar(annees[0],TS[i],width=0.65,label=nom_bassin[i],bottom=TS[i-1])
ax.set_title("Annuel evolution of tropical systems numbers by basin ")
ax.set_xlabel("Years")
ax.set_ylabel("Numbers")
ax.legend()
plt.savefig("OUTPUTS/Annuel_evolution_oft_tropical_systems_numbers_by_basin.jpeg",dpi=1000,bbox_inches="tight")

# %% [markdown]
# ## 2.4

# %% [markdown]
# A répondre

# %% [markdown]
# # 3. TROPICALS SYSTEMS IN MEXICO

# %%
df_temp = datas[datas['SEASON']>1979] #On regarde uniquement les cyclones formés après 1980:
df = df_temp[df_temp['NATURE']=='TS'].fillna(value='NA', inplace=False)#Interprète la valeur NA pour north atlantic comme un nan sinon.

# %% [markdown]
# ## 3.1

# %% [markdown]
# Les bassins qui concerneront Mexico seront EP (Eastern Pacific) et NA (North Atlantic).

# %% [markdown]
# ## 3.2

# %%
#On selectionne les bassins EP et NA pour la zone concernée:
df_mexico = df[df['BASIN'].isin(['EP','NA'])]

# %% [markdown]
# ## 3.3

# %%
df_mexico.drop_duplicates(subset="SID",keep="first").value_counts("BASIN")
# Out:
# BASIN
# EP    751
# NA    574
# dtype: int64

# %%
pd.options.display.max_columns = None
df_mexico
# Out:
#                   SID  SEASON  NUMBER BASIN SUBBASIN     NAME  \
# 424014  1980094N02179    1980      34    EP       CP   CARMEN
# 424015  1980094N02179    1980      34    EP       CP   CARMEN
# 424016  1980094N02179    1980      34    EP       CP   CARMEN
# 424017  1980094N02179    1980      34    EP       CP   CARMEN
# 424018  1980094N02179    1980      34    EP       CP   CARMEN
# ...               ...     ...     ...   ...      ...      ...
# 678431  2018227N37314    2018      56    NA       NA  ERNESTO
# 678432  2018227N37314    2018      56    NA       NA  ERNESTO
# 678433  2018227N37314    2018      56    NA       NA  ERNESTO
# 678434  2018227N37314    2018      56    NA       NA  ERNESTO
# 678435  2018227N37314    2018      56    NA       NA  ERNESTO
#
#                    ISO_TIME NATURE       LAT       LON WMO_WIND WMO_PRES  \
# 424014  1980-04-04 00:00:00     TS   4.74286  181.3710       25
# 424015  1980-04-04 03:00:00     TS   5.34943  181.3310
# 424016  1980-04-04 06:00:00     TS   5.97069  181.2380       25
# 424017  1980-04-04 09:00:00     TS   6.57399  181.1540
# 424018  1980-04-04 12:00:00     TS   7.16000  181.0400       30
# ...                     ...    ...       ...       ...      ...      ...
# 678431  2018-08-17 15:00:00     TS  47.38960  -33.3295
# 678432  2018-08-17 18:00:00     TS  48.30000  -31.8000
# 678433  2018-08-17 21:00:00     TS  49.07710  -29.9332
# 678434  2018-08-18 00:00:00     TS  49.80000  -27.7000
# 678435  2018-08-18 03:00:00     TS  50.51780  -25.0807
#
#        WMO_AGENCY   TRACK_TYPE  DIST2LAND LANDFALL           IFLAG  \
# 424014       cphc         main       2137     2137  O________OO___
# 424015                    main       2204     2204  P________PP___
# 424016       cphc         main       2283     2283  O________OP___
# 424017                    main       2347     2347  P________PP___
# 424018       cphc         main       2418     2418  O________OO___
# ...           ...          ...        ...      ...             ...
# 678431             PROVISIONAL       1441     1441  P_____________
# 678432             PROVISIONAL       1493     1408  O_____________
# 678433             PROVISIONAL       1397     1229  P_____________
# 678434             PROVISIONAL       1222     1030  O_____________
# 678435             PROVISIONAL       1023      821  P_____________
#
#             USA_AGENCY USA_ATCF_ID  USA_LAT   USA_LON USA_RECORD USA_STATUS  \
# 424014         jtwc_wp    WP021980  4.70000  -178.600
# 424015                    WP021980  5.35753  -178.725
# 424016         jtwc_wp    WP021980  6.00000  -178.800
# 424017                    WP021980  6.61495  -178.813
# 424018         jtwc_wp    WP021980  7.20000  -178.900
# ...                ...         ...      ...       ...        ...        ...
# 678431                    AL052018  47.4682  -33.4834                    TS
# 678432  nhc_working_bt    AL052018  48.3000  -31.8000                    TS
# 678433                    AL052018  49.0662  -29.9132                    TS
# 678434  nhc_working_bt    AL052018  49.8000  -27.7000                    TS
# 678435                    AL052018  50.5217  -25.0872                    TS
#
#        USA_WIND USA_PRES USA_SSHS USA_R34_NE USA_R34_SE USA_R34_SW USA_R34_NW  \
# 424014       20                -1
# 424015       22                -1
# 424016       25                -1
# 424017       27                -1
# 424018       30                -1
# ...         ...      ...      ...        ...        ...        ...        ...
# 678431       40     1004        0                   173         92
# 678432       40     1003        0                   185        115
# 678433       40     1001        0                   179        132
# 678434       40      999        0                   173        150
# 678435       37     1000        0                   173        150
#
#        USA_R50_NE USA_R50_SE USA_R50_SW USA_R50_NW USA_R64_NE USA_R64_SE  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...           ...        ...        ...        ...        ...        ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        USA_R64_SW USA_R64_NW USA_POCI USA_ROCI USA_RMW USA_EYE TOKYO_LAT  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...           ...        ...      ...      ...     ...     ...       ...
# 678431                           1012      150      80
# 678432                           1010      150      80
# 678433                           1010      140      85
# 678434                           1010      130      90
# 678435                           1010      130      90
#
#        TOKYO_LON TOKYO_GRADE TOKYO_WIND TOKYO_PRES TOKYO_R50_DIR  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...          ...         ...        ...        ...           ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        TOKYO_R50_LONG TOKYO_R50_SHORT TOKYO_R30_DIR TOKYO_R30_LONG  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...               ...             ...           ...            ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        TOKYO_R30_SHORT TOKYO_LAND CMA_LAT CMA_LON CMA_CAT CMA_WIND CMA_PRES  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...                ...        ...     ...     ...     ...      ...      ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        HKO_LAT HKO_LON HKO_CAT HKO_WIND HKO_PRES NEWDELHI_LAT NEWDELHI_LON  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...        ...     ...     ...      ...      ...          ...          ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        NEWDELHI_GRADE NEWDELHI_WIND NEWDELHI_PRES NEWDELHI_CI NEWDELHI_DP  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...               ...           ...           ...         ...         ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        NEWDELHI_POCI REUNION_LAT REUNION_LON REUNION_TYPE REUNION_WIND  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...              ...         ...         ...          ...          ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        REUNION_PRES REUNION_TNUM REUNION_CI REUNION_RMW REUNION_R34_NE  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...             ...          ...        ...         ...            ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        REUNION_R34_SE REUNION_R34_SW REUNION_R34_NW REUNION_R50_NE  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...               ...            ...            ...            ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        REUNION_R50_SE REUNION_R50_SW REUNION_R50_NW REUNION_R64_NE  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...               ...            ...            ...            ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        REUNION_R64_SE REUNION_R64_SW REUNION_R64_NW BOM_LAT BOM_LON BOM_TYPE  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...               ...            ...            ...     ...     ...      ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        BOM_WIND BOM_PRES BOM_TNUM BOM_CI BOM_RMW BOM_R34_NE BOM_R34_SE  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...         ...      ...      ...    ...     ...        ...        ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        BOM_R34_SW BOM_R34_NW BOM_R50_NE BOM_R50_SE BOM_R50_SW BOM_R50_NW  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...           ...        ...        ...        ...        ...        ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        BOM_R64_NE BOM_R64_SE BOM_R64_SW BOM_R64_NW BOM_ROCI BOM_POCI BOM_EYE  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...           ...        ...        ...        ...      ...      ...     ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        BOM_POS_METHOD BOM_PRES_METHOD NADI_LAT NADI_LON NADI_CAT NADI_WIND  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...               ...             ...      ...      ...      ...       ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        NADI_PRES WELLINGTON_LAT WELLINGTON_LON WELLINGTON_WIND  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...          ...            ...            ...             ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        WELLINGTON_PRES DS824_LAT DS824_LON DS824_STAGE DS824_WIND DS824_PRES  \
# 424014                   4.70000   181.400          TC         20
# 424015                   5.35753  -178.725          TC         22
# 424016                   6.00000   181.200          TC         25
# 424017                   6.61495  -178.813          TC         27
# 424018                   7.20000   181.100          TC         30
# ...                ...       ...       ...         ...        ...        ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        TD9636_LAT TD9636_LON TD9636_STAGE TD9636_WIND TD9636_PRES TD9635_LAT  \
# 424014    4.70000   -178.600            0          20
# 424015    5.26604   -178.497            0          22
# 424016    5.90474   -178.525            0          25
# 424017    6.56607   -178.666            0          27
# 424018    7.20000   -178.900            1          30
# ...           ...        ...          ...         ...         ...        ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        TD9635_LON TD9635_WIND TD9635_PRES TD9635_ROCI NEUMANN_LAT NEUMANN_LON  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...           ...         ...         ...         ...         ...         ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        NEUMANN_CLASS NEUMANN_WIND NEUMANN_PRES MLC_LAT MLC_LON MLC_CLASS  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...              ...          ...          ...     ...     ...       ...
# 678431
# 678432
# 678433
# 678434
# 678435
#
#        MLC_WIND MLC_PRES USA_GUST BOM_GUST BOM_GUST_PER REUNION_GUST  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...         ...      ...      ...      ...          ...          ...
# 678431
# 678432                         50
# 678433
# 678434                         50
# 678435
#
#        REUNION_GUST_PER USA_SEAHGT USA_SEARAD_NE USA_SEARAD_SE USA_SEARAD_SW  \
# 424014
# 424015
# 424016
# 424017
# 424018
# ...                 ...        ...           ...           ...           ...
# 678431                          12            90           255           210
# 678432                          12            90           270           240
# 678433                          12            90           270           255
# 678434                          12            90           270           270
# 678435                          12            90           240           285
#
#        USA_SEARAD_NW STORM_SPEED STORM_DIR
# 424014                        11         9
# 424015                        12       354
# 424016                        12       352
# 424017                        12       350
# 424018                        12       342
# ...              ...         ...       ...
# 678431            75          27        47
# 678432            90          28        53
# 678433            90          31        61
# 678434            90          34        65
# 678435            90          38        68
#
# [59032 rows x 163 columns]
